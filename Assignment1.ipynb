# %% [markdown]
# <a href="https://colab.research.google.com/github/Aff-Code/121-Assignment-1/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CISC 121 – Assignment-1
#
# ## 🔗 Problem
# Fizz Buzz – https://leetcode.com/problems/fizz-buzz/
#
# Palindrome Number – https://leetcode.com/problems/palindrome-number/
#
# Reverse Integer – https://leetcode.com/problems/reverse-integer/
#
# Two Sum – https://leetcode.com/problems/two-sum/
#
# Valid Palindrome – https://leetcode.com/problems/valid-palindrome/

# %% [markdown]
# #  Problem 2 (Palindrome Number)

# %% [markdown]
# ## 1. Understanding & Breakdown
#
# We are provided with an integer 'x' and have been asked to evaluate whether this integer is a palindrome or not. A palindrome is a number that is the same if it is reversed (Such as the number 121 that is given in the assignment is the same if reversed (121))
#
# The inputs would be integers that are either positive or negative and the output would be either a True or False (Boolean) depending on what the answer is
#
# The constraints would be the fact that as provided by the example, negative numbers can never be palindromes as reversing them would bring the negative sign on either side.
# ![WhatsApp Image 2025-09-21 at 8.37.21 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# **Review Guidance:**
# Visit the **"Solutions"** tab on LeetCode for the selected problem and review at least one top-rated solution. You may also search for relevant discussions or Q&A threads on **Stack Overflow** or other forums to understand how others approached the problem.
#
# Then, write your own version based on what you understood. The goal is not to copy but to apply what you learned. Always include links to the resources you reviewed.
#
# ---
#
# ### **Example Answer (for "Palindrome Number"):**
#
# I went through the 'Remainder' solution in the leetcodes solutions tab and realised I could continously take the remainder of an integer ( x % 10).
#
# I also learnt that if we check for the number being a negative at the start, I could avoid executing a lot of the code

# %%
# Your draft code here (does not need to be fully correct)
def isPalindrome(x:int) -> bool:

if x < 0:
  return false

ReversedNum = 0
Original = x

while x > 0:
  ReversedNum = (ReversedNum * 10) + (x % 10)
  x //= 10

return ReversedNum == Original
# Out:
#   File "/tmp/ipython-input-4131229014.py", line 2
#     def isPalindrome(x: int) -> bool
#                                     ^
# SyntaxError: expected ':'

# %% [markdown]
# ## 3. Final Correct Code
#
# _This version must pass all required test cases and handle edge cases correctly._
#
# At this stage, you may:
# - Use reviewed solutions or programming AI tools (e.g., ChatGPT, GitHub Copilot) to refine and fix errors.
# - Refactor your draft to ensure accuracy and completeness.
#
#  **AI Level 4 is allowed**, but you **must include a disclaimer** that clearly states what tools you used, how you used them, and for which part of the code.

# %%
def isPalindrome(x:int) -> bool:
if x < 0:
  return false

if x % 10 == 0 and x != 0:
  return False

ReversedNum = 0
Original = x

while x > 0:
  ReversedNum = (ReversedNum * 10) + (x % 10)
  x //= 10

return ReversedNum == Original

# %% [markdown]
# Add the screenshot of output for all the test cases from your working solutions.

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# Fix 1: Changed the inital code to also verify numbers with trailing 0's

# %% [markdown]
# ## 5. Reflection on Your Contribution
# _Where did AI or Other's code helped or fail to help? What specific logic or debugging did you contribute yourself?_
#
# ## Answer
# 1. Most of the logic and working behind the code was what I had known, however, going through the leetcode solutions, I reaslised that I did not check for trailing 0's which I corrected in my final draft

# %% [markdown]
# #  Problem 3 (Reversed Integer)

# %% [markdown]
# ## 1. Understanding & Breakdown
#
# We have a 32 bit integer x that can be either negative or positive. We need to return the output that is gained from reversing said number and have to make sure that it is within the 32 bit range (-2^31, 2^31 -1). If it is outside the range, our output would be 0.
#
# The inputs would be an integer x and the outputs would be either the new reversed number or '0' if it is outside the range
#
# The main code is similar to the palindrome one

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# **Review Guidance:**
# Visit the **"Solutions"** tab on LeetCode for the selected problem and review at least one top-rated solution. You may also search for relevant discussions or Q&A threads on **Stack Overflow** or other forums to understand how others approached the problem.
#
# Then, write your own version based on what you understood. The goal is not to copy but to apply what you learned. Always include links to the resources you reviewed.
#
# ---
#
#
#
# I went through the leetcode solutions and one important detail that I learned was to check the range each time so that overflow does not occur

# %%
def ReverseInt(x: int) -> int:
  Negative = false
  Ans = 0
  if x < 0:
    negative = true
     x = -1 * x

  while > 0

        Ans = Ans * 10 + (x % 10)
        x //= 10

  if Ans <= -2^31 or Ans >= (2^31 -1)
     return 0
  else
      return Ans

# %% [markdown]
# ## 3. Final Correct Code
#
# _This version must pass all required test cases and handle edge cases correctly._
#
# At this stage, you may:
# - Use reviewed solutions or programming AI tools (e.g., ChatGPT, GitHub Copilot) to refine and fix errors.
# - Refactor your draft to ensure accuracy and completeness.
#
#  **AI Level 4 is allowed**, but you **must include a disclaimer** that clearly states what tools you used, how you used them, and for which part of the code.

# %%
def ReverseInt(x: int) -> int:
  Negative = false
  Ans = 0
  if x < 0:
    negative = true
     x = -1 * x

  while > 0


        x //= 10
        if result > ((2^31 -1)- (x % 10)) // 10:
            return 0

          Ans = Ans * 10 + (x % 10)

  if Ans <= -2^31 or Ans >= (2^31 -1)
     return 0
  else
      return Ans

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# Fix 1: Changed the code so that it checks for overflows during the loop rather than after it

# Draft version (manual and repetitive logic)
  while > 0

        Ans = Ans * 10 + (x % 10)
        x //= 10

# Fixed version (cleaner and scalable)
  while > 0


        x //= 10
        if result > ((2^31 -1)- (x % 10)) // 10:
            return 0

          Ans = Ans * 10 + (x % 10)

# %% [markdown]
# ## 5. Reflection on Your Contribution
# _Where did AI or Other's code helped or fail to help? What specific logic or debugging did you contribute yourself?_
#
# ## Example
# 1. I used the leetcodes solutions to understand what the question was asking and how I can ensure the range/overflow. Besides this, most of the code was from myself

# %% [markdown]
# #  Problem 4 (Two Sum)

# %% [markdown]
# ## 1. Understanding & Breakdown
#
# We have an integer array named 'nums' and an integer that we have to find 'target'. The code will return the indices of two different numbers such that their sum is equal to the target number.
#
# The inputs will be the array 'nums' and the target integer 'target' and the outputs will be list of 2 indices such that their sum is equal to target.
#
# One of the more efficient methods would be to use a double loop.

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# **Review Guidance:**
# Visit the **"Solutions"** tab on LeetCode for the selected problem and review at least one top-rated solution. You may also search for relevant discussions or Q&A threads on **Stack Overflow** or other forums to understand how others approached the problem.
#
# Then, write your own version based on what you understood. The goal is not to copy but to apply what you learned. Always include links to the resources you reviewed.
#
# ---
#
# I had already attempted the twosum code multiple times before and as such knew what to do without any peer help

# %%
def twoSum(self, nums, target):
        for i in range(len(nums)):
            for j in range(i + 1, len(nums)):
                if nums[i] + nums[j] == target:
                    return (i, j)
        return ()

# %% [markdown]
# ## 3. Final Correct Code
#
# _This version must pass all required test cases and handle edge cases correctly._
#
# At this stage, you may:
# - Use reviewed solutions or programming AI tools (e.g., ChatGPT, GitHub Copilot) to refine and fix errors.
# - Refactor your draft to ensure accuracy and completeness.
#
#  **AI Level 4 is allowed**, but you **must include a disclaimer** that clearly states what tools you used, how you used them, and for which part of the code.

# %%
# The draft was my final version
def twoSum(self, nums, target):
        for i in range(len(nums)):
            for j in range(i + 1, len(nums)):
                if nums[i] + nums[j] == target:
                    return (i, j)
        return ()

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# N/A

# %% [markdown]
# ## 5. Reflection on Your Contribution
# _Where did AI or Other's code helped or fail to help? What specific logic or debugging did you contribute yourself?_
#
# I had already attempted the twosum problem before in python (once even during an internship interview) due to which I was familiar with the logic and somewhat optimized code. As such, I used no external help

# %% [markdown]
# #  Problem 5 (Valid Palindrome)

# %% [markdown]
# ## 1. Understanding & Breakdown
#
# We have a string s for which we need to figure out if the string is a palindrome by reversing it and seeing if the output is the same as the input. To do this, the string should be made lowercase and must not contain any non-alphanumeric characters.
#
# The input will the the string s and the output would a boolean true or false
#
# One of the solutions could to initliase 2 indices that start from the first string value and one that starts from the last one. We can compare them side by side and if at any instance, they arent equal or they contain an invalid character, we can return a false.

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# **Review Guidance:**
# Visit the **"Solutions"** tab on LeetCode for the selected problem and review at least one top-rated solution. You may also search for relevant discussions or Q&A threads on **Stack Overflow** or other forums to understand how others approached the problem.
#
# Then, write your own version based on what you understood. The goal is not to copy but to apply what you learned. Always include links to the resources you reviewed.
#
# ---
#
# ### **Example Answer (for "Palindrome Number"):**
#
# I went through leet code solutions
#
# Learnt how to change a string to lowercase in python

# %%
def isPalindrome(s: str) -> bool:
        left = 0
        right = len(s) - 1

        while left < right:
            if not s[left].isalnum():
                left += 1
            elif not s[right].isalnum():
                right -= 1
            else:
                if s[left].lower() != s[right].lower():
                    return False
                left += 1
                right -= 1

        return True

# %% [markdown]
# ## 3. Final Correct Code
#
# _This version must pass all required test cases and handle edge cases correctly._
#
# At this stage, you may:
# - Use reviewed solutions or programming AI tools (e.g., ChatGPT, GitHub Copilot) to refine and fix errors.
# - Refactor your draft to ensure accuracy and completeness.
#
#  **AI Level 4 is allowed**, but you **must include a disclaimer** that clearly states what tools you used, how you used them, and for which part of the code.

# %%
# Draft is final

def isPalindrome(s: str) -> bool:
        left = 0
        right = len(s) - 1

        while left < right:
            if not s[left].isalnum():
                left += 1
            elif not s[right].isalnum():
                right -= 1
            else:
                if s[left].lower() != s[right].lower():
                    return False
                left += 1
                right -= 1

        return True

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# N/a

# %% [markdown]
# ## 5. Reflection on Your Contribution
# _Where did AI or Other's code helped or fail to help? What specific logic or debugging did you contribute yourself?_
#
# ## Example
# 1. LeetCode solutions helped me find out about str.isalnum()

# %% [markdown]
# #  Problem 1 (Fizz Buzz)

# %% [markdown]
# ## 1. Understanding & Breakdown
#
# Fizzbuzz is a code in which we are provided by an integer n. If n is divisible by 3, we can an output of 'fizz'. If by 5, then 'buzz' and if by both 3 and 5, then 'fizzbuzz'
#
# The inputs will be the integer 'n' and the outputs will be starting from the intger 1 and will work work its way upto n and will output the 3 strings in between if that integer is divisible by 3,5 or both

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# **Review Guidance:**
# Visit the **"Solutions"** tab on LeetCode for the selected problem and review at least one top-rated solution. You may also search for relevant discussions or Q&A threads on **Stack Overflow** or other forums to understand how others approached the problem.
#
# Then, write your own version based on what you understood. The goal is not to copy but to apply what you learned. Always include links to the resources you reviewed.
#
# ---
#
# Attempted this code before so did not look at any peer materials

# %%
    def fizzBuzz(n):
        i = 1
        while i <= n:
            if i % 3 == 0 and i % 5 == 0:
                print("FizzBuzz")
            elif i % 3 == 0:
                print("Fizz")
            elif i % 5 == 0:
                print("Buzz")
            else:
                print(i)
            i += 1

# %% [markdown]
# ## 3. Final Correct Code
#
# _This version must pass all required test cases and handle edge cases correctly._
#
# At this stage, you may:
# - Use reviewed solutions or programming AI tools (e.g., ChatGPT, GitHub Copilot) to refine and fix errors.
# - Refactor your draft to ensure accuracy and completeness.
#
#  **AI Level 4 is allowed**, but you **must include a disclaimer** that clearly states what tools you used, how you used them, and for which part of the code.

# %%
# Draft is final


def fizzBuzz(n):
        i = 1
        while i <= n:
            if i % 3 == 0 and i % 5 == 0:
                print("FizzBuzz")
            elif i % 3 == 0:
                print("Fizz")
            elif i % 5 == 0:
                print("Buzz")
            else:
                print(i)
            i += 1

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# N/A

# %% [markdown]
# ## 5. Reflection on Your Contribution
# _Where did AI or Other's code helped or fail to help? What specific logic or debugging did you contribute yourself?_
#
# ## Example
# 1. Had attempted this code before so knew the logic and did not refer to any other material

# %% [markdown]
# #  Repeat this template for Problems 2–5
# You may copy-paste the above section 4 more times or duplicate cells in your notebook environment.
#
# Remember:
# Proper attribution
# No copy-pasting from AI or others

# %% [markdown]
# 1. Your Name: Affan Saeed
# 2. Section: 001
# 3. ID: 20552947
# 4. https://github.com/Aff-Code/121-Assignment-1

# %% [markdown]
# # **The most important part of writing code is not the code itself, but the thinking that leads to it. Thank You**
